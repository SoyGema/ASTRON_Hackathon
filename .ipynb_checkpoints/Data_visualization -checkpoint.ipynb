# %% [markdown]
# ### Astronomy RADIO data from GALAXIES

# %%
import numpy as np
import pandas as pd
from astropy.table import Table
import seaborn as sns
import matplotlib.pyplot as plt

dat = Table.read('high_low_freq_peakedspectrum_table.fits', format='fits')
df = dat.to_pandas()

# %%
col_names = ['S_p', 'nu_p', 'alpha_thin', 'alpha_thick', 'RA_gleam', 'Dec_gleam']
X=df[col_names]
X=X.dropna()

# %%
sns.heatmap(X.corr())

# %%
fig, ax = plt.subplots(figsize=(15,12))

corr = df.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values, ax=ax)
plt.show()

# %%
#%matplotlib tk 
# plots appear in a different window
# %matplotlib inline

# %%
# rows  clustered 
sns.clustermap(X.corr(), method="ward" ,center=0, col_cluster=True,
                annot=True,
               linewidths=.75, figsize=(15, 15), standard_scale=0)
